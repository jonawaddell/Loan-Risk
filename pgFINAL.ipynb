# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits

# %%
loan_data_file = "Update_loans49.csv"

# %%
loan_data = pd.read_csv('loans49.csv',encoding = 'iso-8859-1')
loan_data = pd.read_csv('loans49.csv')

# %%
### accepted loans
loan_data.set_index('issue_d', inplace=True)
all_data_declined.set_index('Application Date', inplace=True)

# changing index (issue_d) to datetime (date-month-year-time) 
loan_data.index = pd.to_datetime(loan_data.index)
loan_data_d.index = pd.to_datetime(.index)

# sorting the columns
all_data.sort_index(axis=1, inplace=True)
all_data_declined.sort_index(axis=1, inplace=True)

# %%
totalloans_bytime = all_data.groupby(all_data.index)['zip_code'].count()
totalloans_bytime.plot(kind='line', fontsize=7)
